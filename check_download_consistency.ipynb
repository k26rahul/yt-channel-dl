# %%
def check_download_consistency():
  """
  Verify download consistency for all videos listed in 'downloads/metadata.json'.

  This function ensures that:
    1. Each video entry in metadata.json has its corresponding .mp4 file in 'downloads/videos'.
    2. Each .mp4 file contains an audio track (verifies with ffprobe).

  It uses yt-dlp's prepare_filename() to determine the exact expected filenames,
  guaranteeing a perfect match with yt-dlp's naming convention.

  Prints a summary showing missing or audio-less files, if any.
  Does not modify any files or data.
  """

  import json
  import subprocess
  from pathlib import Path
  from yt_dlp import YoutubeDL

  meta_path = Path("downloads/metadata.json")
  videos_dir = Path("downloads/videos")

  if not meta_path.exists():
    print("❌ metadata.json missing.")
    return
  if not videos_dir.exists():
    print("❌ videos directory missing.")
    return

  metadata = json.loads(meta_path.read_text(encoding="utf-8"))

  ydl_opts = {"outtmpl": str(videos_dir / "%(title).120B [%(id)s].%(ext)s")}
  ydl = YoutubeDL(ydl_opts)

  print("\n=== Checking download consistency ===")

  missing_files = []
  no_audio_files = []
  total = len(metadata)

  def has_audio(path: Path) -> bool:
    """Return True if file has at least one audio stream."""
    try:
      result = subprocess.run(
          [
              "ffprobe", "-v", "error",
              "-select_streams", "a",
              "-show_entries", "stream=index",
              "-of", "csv=p=0",
              str(path)
          ],
          capture_output=True, text=True
      )
      return bool(result.stdout.strip())
    except FileNotFoundError:
      print("⚠️ ffprobe not found — cannot verify audio tracks.")
      return True  # assume OK if ffprobe missing

  for v in metadata:
    info = {"title": v["title"], "id": v["id"], "ext": "mp4"}
    file_path = Path(ydl.prepare_filename(info))

    if not file_path.exists():
      missing_files.append(file_path)
      print(f"❌ File not found: {file_path}")
      continue

    if not has_audio(file_path):
      no_audio_files.append(file_path)
      print(f"⚠️ No audio track found: {file_path}")

  if not missing_files and not no_audio_files:
    print(f"✅ All {total} videos are present and contain audio tracks.")
  else:
    print("\n--- Summary ---")
    if missing_files:
      print(f"❌ Missing files: {len(missing_files)}")
    if no_audio_files:
      print(f"⚠️ Videos without audio: {len(no_audio_files)}")
    print(f"Total checked: {total}")

# %%
check_download_consistency()
# Out:
# === Checking download consistency ===
# ⚠️ No audio track found: downloads\videos\Azaadi Ka Ambruth Mahotsav [E0usTcu97as].mp4
# ⚠️ No audio track found: downloads\videos\Azaadi Ka Ambruth Mahotsav [Mbm0iOrdqGU].mp4
# ⚠️ No audio track found: downloads\videos\Azaadi Ka Ambruth Mahotsav [6hcJ63Tb5ec].mp4
# ⚠️ No audio track found: downloads\videos\Azaadi Ka Ambruth Mahothsav [z_ngORJjSEU].mp4
# ⚠️ No audio track found: downloads\videos\ಮತ್ಸ್ಯ ನಾರಾಯಣ ಕಲ್ಯಾಣೋತ್ಸವ.... [HKfKG1-uuyY].mp4
# ⚠️ No audio track found: downloads\videos\Azaadi Ka Ambruth Mahothsav... [tOJnxjBsBNw].mp4
# ⚠️ No audio track found: downloads\videos\ಶ್ರೀ ಚಾಮುಂಡೇಶ್ವರಿ ಪಾಲಯಮಾಂ⧸Sri chamundeshwari palayamam⧸Raaga ： ಬಿಲ [K6DZuf9fHPU].mp4
# ⚠️ No audio track found: downloads\videos\Mangala Nidhi program [zrHvVy0DsKw].mp4
# ⚠️ No audio track found: downloads\videos\ಶ್ರೀ ಚಾಮುಂಡೇಶ್ವರಿ ಪಾಲಯಮಾಂ ⧸ ವಿಲಂಬಕಾಲದ ಕೀರ್ತನ [v0RyCwPiUTs].mp4
# ⚠️ No audio track found: downloads\videos\ಶ್ರೀ ಚಾಮುಂಡೇಶ್ವರಿ ಪಾಲಯಮಾಂ⧸Sri   Paalayamam⧸ Vilambakaala Keerthane｜ Bilaah [eNslNnj7uq0].mp4
# ⚠️ No audio track found: downloads\videos\ವರ್ಣಗಳು： ವನಜಾಕ್ಷಿ ⧸Kalyani ： Raaga ｜ Thaala ： Aadi｜  Varna. [xLuvfr0t5v4].mp4
# ⚠️ No audio track found: downloads\videos\ಮಾಮವ ಮೃಡ ಜಾಯೆ⧸Vasantha Raaga⧸Aadi thaala⧸ Vilamba kaala Keerthana. [W3-Ig71dUCs].mp4
# ⚠️ No audio track found: downloads\videos\ನಾದಸ್ವರ⧸Naadaswara Music｜ MangalaVadyam｜ Carnatic Instrumental [zE_8sD3RaM8].mp4
# ⚠️ No audio track found: downloads\videos\ವರವ ಕೊಡು ಎನಗೆ ವಾಗ್ದೇವಿ⧸ Kannada devotional song. Sharada Devi Song. [ACDI9J4WlzA].mp4
# ⚠️ No audio track found: downloads\videos\ವಾತಾಪಿ ಗಣಪತಿಂ ಭಾಜೆಹಂ⧸Vaathaapi ganapathim⧸ Thaala：Aadi⧸Raaga Hamsadwani. [M4kixxmtx1Q].mp4
# ⚠️ No audio track found: downloads\videos\ಪರಮ ಪುರುಷ ಜಗದೀಶ್ವರ ｜ Raga ： Vasantha｜ Thaala ： Aadi｜ [bn9XpAZGmOw].mp4
# ⚠️ No audio track found: downloads\videos\ಪ್ರಣಮಾಮ್ಯಾಹಮ್ ಶ್ರೀ ಗೌರಿ ಸುತಂ ｜ Gowla ： Raaga｜ ......... [m2ktqVaYyY0].mp4
# ⚠️ No audio track found: downloads\videos\ದೇವಿ ಭುವನ ಮನ ಮೋಹಿನಿ⧸ Devi Bhuvana Mana  Mohini...... [8-Yxf447FOw].mp4
# ⚠️ No audio track found: downloads\videos\ಸುಧಾಮಯಿ ಸುಧಾನಿದೆ  ⧸Ambrutha Varshini ： Raaga⧸Aadi Thaala. [G8mXoH0rzFs].mp4
# ⚠️ No audio track found: downloads\videos\ನವರಾತ್ರಿಯ ಹಾಡು⧸ Navaratri Hadu ⧸Navaratrialy Navaraaga Malike Haduve . [wIK0BLPN3-I].mp4
# ⚠️ No audio track found: downloads\videos\ಪ್ರಣಮಾಮ್ಯಹಮ್ ಶ್ರೀ ಗೌರಿಸುತಮ್ Pranamamyahum Sri Gouri Sutham by Shastri  [-pLiTtIfLF0].mp4
# ⚠️ No audio track found: downloads\videos\ಬಂಟು ರೀತಿ ಕೋಲು⧸ Bantureethi kolu ｜ Raaga ： Hamsanaada ｜ Aadi  ： Thaala｜Song  by Shastri Sisters. [srXSe9FgyS4].mp4
# ⚠️ No audio track found: downloads\videos\Thana Varna： Raga： Abhogi, Evvari bhoda. [v4M8jPYyp4k].mp4
# ⚠️ No audio track found: downloads\videos\ಮಾಯಾತಿತ ಸ್ವರೂಪಿಣಿ Keerthane ： Mayamalva goula [2NNynrHhVl8].mp4
# ⚠️ No audio track found: downloads\videos\Thana Varnas⧸Sri：Raaga⧸Aadi Thala. [xebjPEEQY5M].mp4
# ⚠️ No audio track found: downloads\videos\ಇನ್ನಷ್ಟೂ ಬೇಕೇನ್ನ ರಾಮ ｜ INNASTU BEKENNA HRUDAKKE RAMA SONG. [eIRvMCP69js].mp4
# ⚠️ No audio track found: downloads\videos\Varnas⧸Vasantha ： Raaga⧸Aadi Thala. [hAV4L_BZjrU].mp4
# ⚠️ No audio track found: downloads\videos\Thana Varnas⧸Shankara Bharana：Raaga⧸Aadi Thala. [wJxADamaU0U].mp4
# ⚠️ No audio track found: downloads\videos\Swara jathi⧸ Bilahari：Raga⧸Aadi Thala. [LU4ToPLpXpk].mp4
# ⚠️ No audio track found: downloads\videos\Jathi Swara⧸Hamsadhwani：Raga⧸Aadi Thala. [arXhJPvesyg].mp4
# ⚠️ No audio track found: downloads\videos\ರಾಮಾನಾಮಮ್ ಭಾಜೋರೆ ಮಾನಸ ⧸ Raaga： Madhyamavathi⧸Keerthane. [Hv-_RiUBuCs].mp4
# ⚠️ No audio track found: downloads\videos\ಹಿಮಾದ್ರಿ ಸುತೆ⧸ Raaga： Kalyani⧸Thaala ： Rupaka Thala⧸ Keerthane. [GBwrATWw6bI].mp4
# ⚠️ No audio track found: downloads\videos\Jathi Swara⧸ Kharahara Priya ： Raaga⧸Aadi Thala. [4MzNtyv0BNE].mp4
# ⚠️ No audio track found: downloads\videos\Laxna geethe⧸Kalyani ： Raga⧸Aadi Thala. [AmnwootUs4k].mp4
# ⚠️ No audio track found: downloads\videos\ವಳ್ಳಿ ನಾಯಕವೇ  ನೀವೆ ： Keerthane ： Shanmukha Priya ： Raaga⧸Valli Nayaka neeve............. [iETzUrU0fIg].mp4
# ⚠️ No audio track found: downloads\videos\Laxna Geethe⧸Hamsadhwani ： Raga⧸Triputa Thala. [vX2exLRR4_I].mp4
# ⚠️ No audio track found: downloads\videos\Keerthane： Arabhi ： Raaga ⧸ಚೂತಮುರಾರೆ [4KDk1NR4hFI].mp4
# ⚠️ No audio track found: downloads\videos\Sanchari Geethe⧸Naati Kuranji⧸Rupaka Thala. [6RwKeaEzfLg].mp4
# ⚠️ No audio track found: downloads\videos\Sanchari Geethe⧸Kalyani ： geethe⧸Triputa Thala. [FHbW8nvRVSs].mp4
# ⚠️ No audio track found: downloads\videos\Sanchari geethe⧸ Ananda bhairavi：Raga. [hVUiKGKrl2M].mp4
# ⚠️ No audio track found: downloads\videos\Sanchari geethe⧸Begade ： Raaga⧸Triputa Thala. [ydlc1A7Ybhw].mp4
# ⚠️ No audio track found: downloads\videos\ಮಹಾಗಣಪತಿ ⧸ Keerthane： Hamsadhwani ： Raaga⧸Thaala ： Aadi⧸ Mahaganapati...... [TETcWWTHZ3E].mp4
# ⚠️ No audio track found: downloads\videos\ಮಾಮವತು ಶ್ರೀ⧸ Keerthane：Hindola ： Raaga ⧸Thaala：  Aadi⧸ Mamavathu Sri Saraswati..... [9QXz_96k-54].mp4
# ⚠️ No audio track found: downloads\videos\Sanchari geethe⧸ Kalyani：Raaga⧸Triputa thala. [rGwcwGxlROw].mp4
# ⚠️ No audio track found: downloads\videos\Sanchari geethe⧸ Kamboji ： Raaga⧸Aadi Thala. [HIBHuVZAwCQ].mp4
# ⚠️ No audio track found: downloads\videos\Sanchari geethe⧸Mohana： Raaga⧸Vara veena. [ReIl8IG50a0].mp4
# ⚠️ No audio track found: downloads\videos\ಶುದ್ದಸಾವೇರಿ ⧸Keerthane ： Raaga：Shudhasaveri ⧸Sri Guru guha..... [NE-yKL3uqJ0].mp4
# ⚠️ No audio track found: downloads\videos\Pillari geethe⧸ Malahari：Raga⧸Triputa Thala. [b8UYu3c32jM].mp4
# ⚠️ No audio track found: downloads\videos\Keerthane： ಶಂಕರಿನಿ  ನೆ Raaga： Kamaverdhini⧸ Shankarini. [MO8PnRH312k].mp4
# ⚠️ No audio track found: downloads\videos\Pillari geethe⧸Lambhodara lakumikara... [3RqxYoOmUg4].mp4
# ⚠️ No audio track found: downloads\videos\Alankara, khanda jaathi,atta thala. [7qY-wfqvsw0].mp4
# ⚠️ No audio track found: downloads\videos\Chathurasya jaathi matyathala Alankara [iColDsxx1jI].mp4
# ⚠️ No audio track found: downloads\videos\Chathurasya jaathi jhumpethala, alankara [EKFRd9FE3sI].mp4
# ⚠️ No audio track found: downloads\videos\Trishya jaathi thiputathala⧸Carnatic classical music Classes lesson no 3. [PWyP0vaAJWs].mp4
# ⚠️ No audio track found: downloads\videos\Chathurasya jaathi rupakathala, alankara.. [NlJ04DundDE].mp4
# ⚠️ No audio track found: downloads\videos\Chathurasya jaathi ekathala, alankara. [SZZC7oHRvGY].mp4
# ⚠️ No audio track found: downloads\videos\Ganesh pancharatnam [J82NUH2N0t8].mp4
# ⚠️ No audio track found: downloads\videos\Mahalaxmi Astakam. [FK77kzp03HM].mp4
# ⚠️ No audio track found: downloads\videos\Medhasukta [9Cxb92oR1Xw].mp4
# ⚠️ No audio track found: downloads\videos\Carnatic classical music Classes Mandra-sthai. [jsMjkrID010].mp4
# ⚠️ No audio track found: downloads\videos\Carnatic Music for Children ......Thara-sthai [cbID6sF5UK0].mp4
#
# --- Summary ---
# ⚠️ Videos without audio: 61
# Total checked: 67
